# %%
# %reload_kedro
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
# Out:
# [01/02/24 20:44:41] INFO     Resolved project path as:                                              ]8;id=373747;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=491793;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py#139\139]8;;\
#                              /home/joelmashana/IRP/joel-mashana-dissertation-project.
#                              To set a different path, run '%reload_kedro <project_root>'
# [01/02/24 20:44:41] INFO     Kedro project Joel Mashana Dissertation Project                        ]8;id=269447;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=360247;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py#108\108]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=655590;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=114516;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py#109\109]8;;\
#                              'pipelines'
#                     INFO     Registered line magic 'run_viz'                                        ]8;id=24116;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=987526;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py#115\115]8;;\

# %%
df = catalog.load('buyer_payment_practice_dataset_mean_imputed')
# Out:
#                     INFO     Loading data from 'buyer_payment_practice_dataset_mean_imputed'    ]8;id=243847;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=418054;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/io/data_catalog.py#492\492]8;;\
#                              (CSVDataSet)...

# %%
# Average time to pay 
mean_value = df['Average time to pay'].mean()

# %%
mean_value
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 49.42815794914203

# %%
# Assuming your dependent variable is named 'target' and the rest are independent variables
dependent_var = 'Risk Level'
independent_vars = df.columns.difference([dependent_var])

# Check for linearity with log odds
# Logistic regression requires a linear relationship between independent variables and log odds
for ivar in independent_vars:
    sns.scatterplot(x=df[ivar], y=df[dependent_var])
    plt.title(f"Relationship between {ivar} and {dependent_var}")
    plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %%
# Check for multicollinearity using Variance Inflation Factor (VIF)
# VIF starts at 1 and has no upper limit. VIF > 10 indicates high multicollinearity.
X = df[independent_vars]
X['intercept'] = 1  # Adding constant for VIF calculation
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
print(vif_data)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:7                                                                                    │
# │                                                                                                  │
# │    4 X['intercept'] = 1  # Adding constant for VIF calculation                                   │
# │    5 vif_data = pd.DataFrame()                                                                   │
# │    6 vif_data['feature'] = X.columns                                                             │
# │ ❱  7 vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))    │
# │    8 print(vif_data)                                                                             │
# │    9                                                                                             │
# │   10                                                                                             │
# │                                                                                                  │
# │ in <listcomp>:7                                                                                  │
# │                                                                                                  │
# │    4 X['intercept'] = 1  # Adding constant for VIF calculation                                   │
# │    5 vif_data = pd.DataFrame()                                                                   │
# │    6 vif_data['feature'] = X.columns                                                             │
# │ ❱  7 vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))    │
# │    8 print(vif_data)                                                                             │
# │    9                                                                                             │
# │   10                                                                                             │
# │                                                                                                  │
# │ /home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/statsm │
# │ odels/stats/outliers_influence.py:197 in variance_inflation_factor                               │
# │                                                                                                  │
# │    194 │   x_i = exog[:, exog_idx]                                                               │
# │    195 │   mask = np.arange(k_vars) != exog_idx                                                  │
# │    196 │   x_noti = exog[:, mask]                                                                │
# │ ❱  197 │   r_squared_i = OLS(x_i, x_noti).fit().rsquared                                         │
# │    198 │   vif = 1. / (1. - r_squared_i)                                                         │
# │    199 │   return vif                                                                            │
# │    200                                                                                           │
# │                                                                                                  │
# │ /home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/statsm │
# │ odels/regression/linear_model.py:922 in __init__                                                 │
# │                                                                                                  │
# │    919 │   │   │   msg = ("Weights are not supported in OLS and will be ignored"                 │
# │    920 │   │   │   │      "An exception will be raised in the next version.")                    │
# │    921 │   │   │   warnings.warn(msg, ValueWarning)                                              │
# │ ❱  922 │   │   super(OLS, self).__init__(endog, exog, missing=missing,                           │
# │    923 │   │   │   │   │   │   │   │     hasconst=hasconst, **kwargs)                            │
# │    924 │   │   if "weights" in self._init_keys:                                                  │
# │    925 │   │   │   self._init_keys.remove("weights")                                             │
# │                                                                                                  │
# │ /home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/statsm │
# │ odels/regression/linear_model.py:748 in __init__                                                 │
# │                                                                                                  │
# │    745 │   │   │   weights = np.array([weights.squeeze()])                                       │
# │    746 │   │   else:                                                                             │
# │    747 │   │   │   weights = weights.squeeze()                                                   │
# │ ❱  748 │   │   super(WLS, self).__init__(endog, exog, missing=missing,                           │
# │    749 │   │   │   │   │   │   │   │     weights=weights, hasconst=hasconst, **kwargs)           │
# │    750 │   │   nobs = self.exog.shape[0]                                                         │
# │    751 │   │   weights = self.weights                                                            │
# │                                                                                                  │
# │ /home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/statsm │
# │ odels/regression/linear_model.py:202 in __init__                                                 │
# │                                                                                                  │
# │    199 │   Intended for subclassing.                                                             │
# │    200 │   """                                                                                   │
# │    201 │   def __init__(self, endog, exog, **kwargs):                                            │
# │ ❱  202 │   │   super(RegressionModel, self).__init__(endog, exog, **kwargs)                      │
# │    203 │   │   self.pinv_wexog: Float64Array | None = None                                       │
# │    204 │   │   self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])              │
# │    205                                                                                           │
# │                                                                                                  │
# │ /home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/statsm │
# │ odels/base/model.py:270 in __init__                                                              │
# │                                                                                                  │
# │    267 │   """                                                                                   │
# │    268 │                                                                                         │
# │    269 │   def __init__(self, endog, exog=None, **kwargs):                                       │
# │ ❱  270 │   │   super().__init__(endog, exog, **kwargs)                                           │
# │    271 │   │   self.initialize()                                                                 │
# │    272 │                                                                                         │
# │    273 │   def initialize(self):                                                                 │
# │                                                                                                  │
# │ /home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/statsm │
# │ odels/base/model.py:95 in __init__                                                               │
# │                                                                                                  │
# │     92 │   def __init__(self, endog, exog=None, **kwargs):                                       │
# │     93 │   │   missing = kwargs.pop('missing', 'none')                                           │
# │     94 │   │   hasconst = kwargs.pop('hasconst', None)                                           │
# │ ❱   95 │   │   self.data = self._handle_data(endog, exog, missing, hasconst,                     │
# │     96 │   │   │   │   │   │   │   │   │     **kwargs)                                           │
# │     97 │   │   self.k_constant = self.data.k_constant                                            │
# │     98 │   │   self.exog = self.data.exog                                                        │
# │                                                                                                  │
# │ /home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/statsm │
# │ odels/base/model.py:135 in _handle_data                                                          │
# │                                                                                                  │
# │    132 │   │   │   │   raise ValueError(msg)                                                     │
# │    133 │                                                                                         │
# │    134 │   def _handle_data(self, endog, exog, missing, hasconst, **kwargs):                     │
# │ ❱  135 │   │   data = handle_data(endog, exog, missing, hasconst, **kwargs)                      │
# │    136 │   │   # kwargs arrays could have changed, easier to just attach here                    │
# │    137 │   │   for key in kwargs:                                                                │
# │    138 │   │   │   if key in ['design_info', 'formula']:  # leave attached to data               │
# │                                                                                                  │
# │ /home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/statsm │
# │ odels/base/data.py:675 in handle_data                                                            │
# │                                                                                                  │
# │   672 │   │   exog = np.asarray(exog)                                                            │
# │   673 │                                                                                          │
# │   674 │   klass = handle_data_class_factory(endog, exog)                                         │
# │ ❱ 675 │   return klass(endog, exog=exog, missing=missing, hasconst=hasconst,                     │
# │   676 │   │   │   │    **kwargs)                                                                 │
# │   677                                                                                            │
# │                                                                                                  │
# │ /home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/statsm │
# │ odels/base/data.py:88 in __init__                                                                │
# │                                                                                                  │
# │    85 │   │                                                                                      │
# │    86 │   │   self.const_idx = None                                                              │
# │    87 │   │   self.k_constant = 0                                                                │
# │ ❱  88 │   │   self._handle_constant(hasconst)                                                    │
# │    89 │   │   self._check_integrity()                                                            │
# │    90 │   │   self._cache = {}                                                                   │
# │    91                                                                                            │
# │                                                                                                  │
# │ /home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/statsm │
# │ odels/base/data.py:133 in _handle_constant                                                       │
# │                                                                                                  │
# │   130 │   │   │   # detect where the constant is                                                 │
# │   131 │   │   │   check_implicit = False                                                         │
# │   132 │   │   │   exog_max = np.max(self.exog, axis=0)                                           │
# │ ❱ 133 │   │   │   if not np.isfinite(exog_max).all():                                            │
# │   134 │   │   │   │   raise MissingDataError('exog contains inf or nans')                        │
# │   135 │   │   │   exog_min = np.min(self.exog, axis=0)                                           │
# │   136 │   │   │   const_idx = np.where(exog_max == exog_min)[0].squeeze()                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any
# supported types according to the casting rule ''safe''

# %%
# Check for outliers
# Box plots for each independent variable to check for outliers
for ivar in independent_vars:
    sns.boxplot(y=df[ivar])
    plt.title(f"Box plot for {ivar}")
    plt.show()
