# %%
# %reload_kedro
from sklearn.tree import plot_tree, export_graphviz
import matplotlib.pyplot as plt
import graphviz
# Out:
# [01/02/24 15:29:02] INFO     Resolved project path as:                                              ]8;id=797560;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=305460;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py#139\139]8;;\
#                              /home/joelmashana/IRP/joel-mashana-dissertation-project.
#                              To set a different path, run '%reload_kedro <project_root>'
# [01/02/24 15:29:02] INFO     Kedro project Joel Mashana Dissertation Project                        ]8;id=271570;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=97911;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py#108\108]8;;\
# ...

# %%
clf = catalog.load('decision_tree_final_model')
# Out:
#                     INFO     Loading data from 'decision_tree_final_model' (PickleDataSet)...   ]8;id=634575;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=835715;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/io/data_catalog.py#492\492]8;;\

# %%
# List of feature names
df = catalog.load('X_train_main')
feature_names = df.columns.tolist()
print(feature_names)
# Out:
#                     INFO     Loading data from 'X_train_main' (CSVDataSet)...                   ]8;id=269483;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=371844;file:///home/joelmashana/IRP/joel-mashana-dissertation-project/.venv/lib/python3.8/site-packages/kedro/io/data_catalog.py#492\492]8;;\
# ['Payments made in the reporting period', 'Average time to pay', '% Invoices paid within 30 days', '% Invoices paid between 31 and 60 days', '% Invoices paid later than 60 days', 'Shortest (or only) standard payment period', 'Longest standard payment period', 'Maximum contractual payment period', 'Payment terms have changed', 'Suppliers notified of changes', 'Participates in payment codes', 'E-Invoicing offered', 'Supply-chain financing offered', 'Policy covers charges for remaining on supplier list', 'Charges have been made for remaining on supplier list']

# %%
feature_names = [
    "Payments made in the reporting period", "Average time to pay",
    "% Invoices paid within 30 days", "% Invoices paid between 31 and 60 days",
    "% Invoices paid later than 60 days", "Shortest (or only) standard payment period",
    "Longest standard payment period", "Maximum contractual payment period",
    "Payment terms have changed", "Suppliers notified of changes",
    "Participates in payment codes", "E-Invoicing offered",
    "Supply-chain financing offered", "Policy covers charges for remaining on supplier list",
    "Charges have been made for remaining on supplier list"
]

for index, feature_name in enumerate(feature_names):
    print(f"Index {index}: {feature_name}")
# Out:
# Index 0: Payments made in the reporting period
# Index 1: Average time to pay
# Index 2: % Invoices paid within 30 days
# Index 3: % Invoices paid between 31 and 60 days
# Index 4: % Invoices paid later than 60 days
# Index 5: Shortest (or only) standard payment period
# Index 6: Longest standard payment period
# Index 7: Maximum contractual payment period
# Index 8: Payment terms have changed
# Index 9: Suppliers notified of changes
# Index 10: Participates in payment codes
# Index 11: E-Invoicing offered
# Index 12: Supply-chain financing offered
# Index 13: Policy covers charges for remaining on supplier list
# Index 14: Charges have been made for remaining on supplier list

# %%
# Extract 
decision_tree_model = clf.named_steps['decisiontreeclassifier']

plt.figure(figsize=(55, 25))  
plot_tree(decision_tree_model, filled=True, fontsize=20)
plt.savefig("decision_tree_high_res.pdf", format='pdf', dpi=300)  
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 5500x2500 with 1 Axes>
